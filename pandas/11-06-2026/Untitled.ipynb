# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = ['Ram','Shreya','Mohan','sohan']
df = pd.DataFrame(data)
df
# Out:
#         0
# 0     Ram
# 1  Shreya
# 2   Mohan
# 3   sohan

# %%
## making dataFrame from list of list

# %%
data = [['Ram',23,89000],['Shyam',22,23000],['Mohan',25,58000],['Vishal',24,70000]]
df=pd.DataFrame(data)

# %%
df
# Out:
#         0   1      2
# 0     Ram  23  89000
# 1   Shyam  22  23000
# 2   Mohan  25  58000
# 3  Vishal  24  70000

# %%
df[1]
# Out:
# 0    23
# 1    22
# 2    25
# 3    24
# Name: 1, dtype: int64

# %%
df=df.rename(columns={0:'Name',1:'Age',2:'Salary'})

# %%
df['Name']
# Out:
# 0       Ram
# 1     Shyam
# 2     Mohan
# 3    Vishal
# Name: Name, dtype: object

# %%
df['Salary'][0]
# Out:
# np.int64(89000)

# %%
## To print the content of row

# %%
df.loc[[0,1]]
# Out:
#     Name  Age  Salary
# 0    Ram   23   89000
# 1  Shyam   22   23000

# %%
df.iloc[0]
# Out:
# Name        Ram
# Age          23
# Salary    89000
# Name: 0, dtype: object

# %%
df.loc[0:3,['first_name','last_name']]
# Out:
#   first_name   last_name
# 0  Margarete     Collopy
# 1      Shari  Charleston
# 2      Quinn    Loffhead
# 3     Idelle      Sleath

# %%
df[['Name','Salary']]
# Out:
#      Name  Salary
# 0     Ram   89000
# 1   Shyam   23000
# 2   Mohan   58000
# 3  Vishal   70000

# %%
## making dataframe using Dictionary

# %%
data = {'name':['Ram','Mohan','Sohan'],
        'age':[21,'',''],
        'marks':[89,90,91]
       }
df= pd.DataFrame(data)

# %%
df
# Out:
#     name age  marks
# 0    Ram  21     89
# 1  Mohan         90
# 2  Sohan         91

# %%
## making data Frame from list of Dictionary

# %%
data = [
        {
            'name':'Ram',
            'age':24,
            'marks':58000
        },
        {
            'name':'vishal',
            'age':21,
            'marks':59000
        },
        {
            'name':'Shaym',
            'age':24,
            'marks':57000
        },
        {
            'Gender':'male',
            'name':'Lalit'
        }        
]

df= pd.DataFrame(data)
df
# Out:
#      name   age    marks Gender
# 0     Ram  24.0  58000.0    NaN
# 1  vishal  21.0  59000.0    NaN
# 2   Shaym  24.0  57000.0    NaN
# 3   Lalit   NaN      NaN   male

# %%
df= pd.read_csv("sample.csv")
df
# Out:
#      id first_name   last_name                         email      gender  \
# 0     1  Margarete     Collopy         mcollopy0@skyrock.com  Polygender
# 1     2      Shari  Charleston          scharleston1@ibm.com      Female
# 2     3      Quinn    Loffhead            qloffhead2@mapy.cz        Male
# 3     4     Idelle      Sleath              isleath3@unc.edu      Female
# 4     5    Barbara    Wolffers    bwolffers4@hugedomains.com      Female
# ..  ...        ...         ...                           ...         ...
# 95   96   Marrissa      Breens          mbreens2n@smh.com.au      Female
# 96   97      Mikey  Burkinshaw  mburkinshaw2o@shutterfly.com        Male
# 97   98        Eva   Guerrieri     eguerrieri2p@google.co.uk      Female
# 98   99      Kalie    Fennelly      kfennelly2q@netscape.com      Female
# 99  100      Jayme    Danielis          jdanielis2r@time.com        Male
#
#          ip_address
# 0      56.20.83.133
# 1      48.171.17.34
# 2   128.211.218.161
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   first_name  100 non-null    object
#  2   last_name   100 non-null    object
#  3   email       100 non-null    object
#  4   gender      100 non-null    object
#  5   ip_address  100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address'], dtype='object')

# %%
df.head()
# Out:
#    id first_name   last_name                       email      gender  \
# 0   1  Margarete     Collopy       mcollopy0@skyrock.com  Polygender
# 1   2      Shari  Charleston        scharleston1@ibm.com      Female
# 2   3      Quinn    Loffhead          qloffhead2@mapy.cz        Male
# 3   4     Idelle      Sleath            isleath3@unc.edu      Female
# 4   5    Barbara    Wolffers  bwolffers4@hugedomains.com      Female
#
#         ip_address
# 0     56.20.83.133
# 1     48.171.17.34
# 2  128.211.218.161
# 3    200.151.79.91
# 4  148.212.173.251

# %%
df.head(10)
# Out:
#    id first_name   last_name                       email      gender  \
# 0   1  Margarete     Collopy       mcollopy0@skyrock.com  Polygender
# 1   2      Shari  Charleston        scharleston1@ibm.com      Female
# 2   3      Quinn    Loffhead          qloffhead2@mapy.cz        Male
# 3   4     Idelle      Sleath            isleath3@unc.edu      Female
# 4   5    Barbara    Wolffers  bwolffers4@hugedomains.com      Female
# 5   6      Patty    Locksley        plocksley5@google.ca        Male
# 6   7     Broddy    Browning  bbrowning6@squarespace.com        Male
# 7   8     Dianna       North              dnorth7@hp.com      Female
# 8   9      Erica      Epinoy        eepinoy8@yahoo.co.jp      Female
# 9  10  Winnifred       Rodge          wrodge9@forbes.com      Female
#
#         ip_address
# 0     56.20.83.133
# 1     48.171.17.34
# 2  128.211.218.161
# 3    200.151.79.91
# 4  148.212.173.251
# 5     45.218.46.58
# 6    1.253.141.119
# 7    62.243.50.204
# 8    26.162.66.187
# ...

# %%
df.tail()
# Out:
#      id first_name   last_name                         email  gender  \
# 95   96   Marrissa      Breens          mbreens2n@smh.com.au  Female
# 96   97      Mikey  Burkinshaw  mburkinshaw2o@shutterfly.com    Male
# 97   98        Eva   Guerrieri     eguerrieri2p@google.co.uk  Female
# 98   99      Kalie    Fennelly      kfennelly2q@netscape.com  Female
# 99  100      Jayme    Danielis          jdanielis2r@time.com    Male
#
#         ip_address
# 95  188.240.159.35
# 96  107.152.194.19
# 97  238.78.171.255
# 98     40.26.72.41
# 99   64.64.138.178

# %%
df= pd.read_csv("sample.csv",usecols=['first_name','last_name'])

# %%
df
# Out:
#    first_name   last_name
# 0   Margarete     Collopy
# 1       Shari  Charleston
# 2       Quinn    Loffhead
# 3      Idelle      Sleath
# 4     Barbara    Wolffers
# ..        ...         ...
# 95   Marrissa      Breens
# 96      Mikey  Burkinshaw
# 97        Eva   Guerrieri
# 98      Kalie    Fennelly
# 99      Jayme    Danielis
#
# [100 rows x 2 columns]

# %%
df= pd.read_csv("sample.csv",nrows=6)

# %%
df
# Out:
#    id first_name   last_name                       email      gender  \
# 0   1  Margarete     Collopy       mcollopy0@skyrock.com  Polygender
# 1   2      Shari  Charleston        scharleston1@ibm.com      Female
# 2   3      Quinn    Loffhead          qloffhead2@mapy.cz        Male
# 3   4     Idelle      Sleath            isleath3@unc.edu      Female
# 4   5    Barbara    Wolffers  bwolffers4@hugedomains.com      Female
# 5   6      Patty    Locksley        plocksley5@google.ca        Male
#
#         ip_address
# 0     56.20.83.133
# 1     48.171.17.34
# 2  128.211.218.161
# 3    200.151.79.91
# 4  148.212.173.251
# 5     45.218.46.58

# %%
data = pd.read_excel("sample.xlsx")
data
# Out:
#      id first_name last_name                    email  gender       ip_address
# 0     1      Nadia    Smylie     nsmylie0@tinyurl.com  Female    14.132.133.60
# 1     2    Frances  Skeleton    fskeleton1@paypal.com  Female  192.213.128.195
# 2     3     Margie  Flintoft     mflintoft2@baidu.com  Female      76.74.88.44
# 3     4  Betteanne  MacCombe     bmaccombe3@globo.com  Female    253.8.169.154
# 4     5   Nikolaos      Lees      nlees4@e-recht24.de    Male    89.223.221.90
# ..  ...        ...       ...                      ...     ...              ...
# 95   96    Ardenia   Downing     adowning2n@ifeng.com  Female    80.137.193.50
# 96   97       Olin     Cruce  ocruce2o@shareasale.com    Male   120.66.220.176
# 97   98     Paulie  Llewelyn     pllewelyn2p@furl.net    Male  116.116.155.238
# 98   99     Nickey      Corp      ncorp2q@twitter.com    Male   177.253.66.232
# 99  100       Brig      Orto        borto2r@intel.com    Male    174.90.251.17
#
# [100 rows x 6 columns]

# %% [markdown]
# ## Loading data from APIs

# %%
import requests

# %%
data=requests.get("https://jsonplaceholder.typicode.com/comments")
fdata=data.json()
df = pd.DataFrame(fdata)
df

# %%
data.loc[0:3,['first_name','last_name']]
# Out:
#   first_name last_name
# 0      Nadia    Smylie
# 1    Frances  Skeleton
# 2     Margie  Flintoft
# 3  Betteanne  MacCombe

# %%
data.loc[:,['first_name','last_name']]
# Out:
#    first_name last_name
# 0       Nadia    Smylie
# 1     Frances  Skeleton
# 2      Margie  Flintoft
# 3   Betteanne  MacCombe
# 4    Nikolaos      Lees
# ..        ...       ...
# 95    Ardenia   Downing
# 96       Olin     Cruce
# 97     Paulie  Llewelyn
# 98     Nickey      Corp
# 99       Brig      Orto
#
# [100 rows x 2 columns]

# %%
data.set_index('first_name',inplace=True)

# %%
data.loc['Nadia']
# Out:
# id                               1
# last_name                   Smylie
# email         nsmylie0@tinyurl.com
# gender                      Female
# ip_address           14.132.133.60
# Name: Nadia, dtype: object
