# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("winedata - sheet1.csv")

# %%
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %% [raw]
# Q1)
# Write a Pandas program to display the dimensions or shape of the World alcohol
# consumption dataset. Also extract the column names from the dataset

# %%
df.shape
# Out:
# (100, 5)

# %%
df.columns
# Out:
# Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %%
# Q2) Write a Pandas program to find out the alcohol consumption details in the year '1987' or '1989' from the world alcohol consumption dataset  
df.query("Year == 1987 | Year == 1989").head()
df.loc[(df["Year"] == 1987) | (df["Year"] == 1989)].head()
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 4   1987   Americas  Saint Kitts and Nevis           Beer           1.98
# 5   1987   Americas              Guatemala          Other           0.00
# 6   1987     Africa              Mauritius           Wine           0.13
# 10  1987     Africa               Botswana           Wine           0.20
# 11  1989   Americas              Guatemala           Beer           0.62

# %%
# Q3) Write a Pandas program to find out the alcohol consumption details by the 'Americas' in the year '1985' from the world alcohol consumption dataset  
# df.loc[(df["Year"] == 1985) & (df["WHO region"] == 'Americas')]
df.query("Year == 1985 and `WHO region` == 'Americas'")
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 35  1985   Americas  Saint Kitts and Nevis        Spirits           2.24

# %%
# Q4) Write a Pandas program to find out the alcohol consumption details in the year '1986' where WHO region is 'Western Pacific' and country is 'VietNam' from the world alcohol consumption dataset.
# df.loc[
#     (df["Year"] == 1986)
#     & (df["WHO region"] == "Western Pacific")
#     & (df["Country"] == "Viet Nam")
# ]
df.query("Year == 1985 and `WHO region` == 'Western Pacific' and Country == 'Viet Nam'")
# Out:
#     Year       WHO region   Country Beverage Types  Display Value
# 14  1985  Western Pacific  Viet Nam        Spirits           0.05

# %%
# Q5) Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset.
df.query("Year == 1986 or Year == 1989 and `WHO region` == 'Americas' or `WHO region` == 'Europe'").head()
# df.loc[
#     (df["Year"] == 1986)
#     | (df["Year"] == 1989) & (df["WHO region"] == "Americas")
#     | (df["WHO region"] == "Europe")
# ].head()
# Out:
#     Year       WHO region              Country Beverage Types  Display Value
# 0   1986  Western Pacific             Viet Nam           Wine           0.00
# 1   1986         Americas              Uruguay          Other           0.50
# 3   1986         Americas             Colombia           Beer           4.27
# 8   1986         Americas  Antigua and Barbuda        Spirits           1.55
# 11  1989         Americas            Guatemala           Beer           0.62
